# %%
import os
import sys
sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
import matplotlib.pyplot as plt

from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD
from common.trainer import Trainer

# %%
class SGD:
    def __init__(self, lr=0.01):
        self.lr = lr
        
    def update(self, params, grads):
        for key in params.keys():
            params[key] -= self.lr * grads[key]

# %%
class Momentum:
    def __init__(self, lr=0.01, momentum=0.9):
        self.lr = lr
        self.momentum = momentum
        self.v = None
        
    def update(self, params, grads):
        if self.v is None:
            self.v = {}
            for key, val in params.items():                                
                self.v[key] = np.zeros_like(val)
                
        for key in params.keys():
            self.v[key] = self.momentum*self.v[key] - self.lr*grads[key] 
            params[key] += self.v[key]

# %%
class AdaGrad:
    def __init__(self, lr=0.01):
        self.lr = lr
        self.h = None
        
    def update(self, params, grads):
        if self.h is None:
            self.h = {}
            for key, val in params.items():
                self.h[key] = np.zeros_like(val)
            
        for key in params.keys():
            self.h[key] += grads[key] * grads[key]
            params[key] -= self.lr * grads[key] / (np.sqrt(self.h[key]) + 1e-7)

# %%
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

x_train = x_train[:300]
t_train = t_train[:300]

#weight_decay_lambda = 0
weight_decay_lambda = 0.1



network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01)

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break


# 3.グラフの描画==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# epoch:0, train acc:0.09333333333333334, test acc:0.0884
# epoch:1, train acc:0.11666666666666667, test acc:0.0981
# epoch:2, train acc:0.13333333333333333, test acc:0.1063
# epoch:3, train acc:0.16333333333333333, test acc:0.1178
# epoch:4, train acc:0.17666666666666667, test acc:0.1295
# epoch:5, train acc:0.20666666666666667, test acc:0.1459
# epoch:6, train acc:0.22333333333333333, test acc:0.161
# epoch:7, train acc:0.23666666666666666, test acc:0.1786
# epoch:8, train acc:0.27666666666666667, test acc:0.1927
# epoch:9, train acc:0.29333333333333333, test acc:0.2011
# epoch:10, train acc:0.31, test acc:0.2106
# epoch:11, train acc:0.31666666666666665, test acc:0.2199
# epoch:12, train acc:0.33, test acc:0.2307
# epoch:13, train acc:0.3433333333333333, test acc:0.2436
# epoch:14, train acc:0.35333333333333333, test acc:0.2502
# epoch:15, train acc:0.37333333333333335, test acc:0.2688
# epoch:16, train acc:0.38333333333333336, test acc:0.2707
# epoch:17, train acc:0.4033333333333333, test acc:0.2898
# epoch:18, train acc:0.4266666666666667, test acc:0.3058
# epoch:19, train acc:0.43666666666666665, test acc:0.3152
# epoch:20, train acc:0.44333333333333336, test acc:0.3241
# epoch:21, train acc:0.44, test acc:0.3362
# epoch:22, train acc:0.43, test acc:0.3408
# epoch:23, train acc:0.46, test acc:0.3459
# epoch:24, train acc:0.47333333333333333, test acc:0.3661
# epoch:25, train acc:0.48333333333333334, test acc:0.3732
# epoch:26, train acc:0.49666666666666665, test acc:0.3859
# epoch:27, train acc:0.49666666666666665, test acc:0.3929
# epoch:28, train acc:0.53, test acc:0.4083
# epoch:29, train acc:0.5266666666666666, test acc:0.4114
# epoch:30, train acc:0.5433333333333333, test acc:0.4209
# epoch:31, train acc:0.5233333333333333, test acc:0.4199
# epoch:32, train acc:0.56, test acc:0.4398
# epoch:33, train acc:0.57, test acc:0.4407
# epoch:34, train acc:0.5766666666666667, test acc:0.4575
# epoch:35, train acc:0.6066666666666667, test acc:0.4635
# epoch:36, train acc:0.5933333333333334, test acc:0.4792
# epoch:37, train acc:0.61, test acc:0.4953
# epoch:38, train acc:0.64, test acc:0.5097
# epoch:39, train acc:0.6533333333333333, test acc:0.5114
# epoch:40, train acc:0.6666666666666666, test acc:0.5203
# epoch:41, train acc:0.6866666666666666, test acc:0.5337
# epoch:42, train acc:0.6966666666666667, test acc:0.5382
# epoch:43, train acc:0.7166666666666667, test acc:0.5615
# epoch:44, train acc:0.7333333333333333, test acc:0.5757
# epoch:45, train acc:0.7166666666666667, test acc:0.5724
# epoch:46, train acc:0.7466666666666667, test acc:0.5939
# epoch:47, train acc:0.7433333333333333, test acc:0.5988
# epoch:48, train acc:0.75, test acc:0.5985
# epoch:49, train acc:0.75, test acc:0.5908
# epoch:50, train acc:0.76, test acc:0.6158
# epoch:51, train acc:0.7733333333333333, test acc:0.6226
# epoch:52, train acc:0.76, test acc:0.6313
# epoch:53, train acc:0.7666666666666667, test acc:0.6326
# epoch:54, train acc:0.78, test acc:0.6418
# epoch:55, train acc:0.7833333333333333, test acc:0.6542
# epoch:56, train acc:0.79, test acc:0.6521
# epoch:57, train acc:0.7866666666666666, test acc:0.6555
# epoch:58, train acc:0.78, test acc:0.6563
# epoch:59, train acc:0.78, test acc:0.6533
# epoch:60, train acc:0.79, test acc:0.6533
# epoch:61, train acc:0.8, test acc:0.6726
# epoch:62, train acc:0.81, test acc:0.6715
# epoch:63, train acc:0.8066666666666666, test acc:0.673
# epoch:64, train acc:0.7966666666666666, test acc:0.6692
# epoch:65, train acc:0.7933333333333333, test acc:0.6618
# epoch:66, train acc:0.7966666666666666, test acc:0.6719
# epoch:67, train acc:0.7933333333333333, test acc:0.6705
# epoch:68, train acc:0.81, test acc:0.6771
# epoch:69, train acc:0.8033333333333333, test acc:0.6741
# epoch:70, train acc:0.8066666666666666, test acc:0.6757
# epoch:71, train acc:0.8066666666666666, test acc:0.6848
# epoch:72, train acc:0.8266666666666667, test acc:0.6901
# epoch:73, train acc:0.8133333333333334, test acc:0.6871
# epoch:74, train acc:0.82, test acc:0.6865
# epoch:75, train acc:0.81, test acc:0.6779
# epoch:76, train acc:0.8266666666666667, test acc:0.6909
# epoch:77, train acc:0.8266666666666667, test acc:0.6855
# epoch:78, train acc:0.8233333333333334, test acc:0.6854
# epoch:79, train acc:0.8033333333333333, test acc:0.6751
# epoch:80, train acc:0.82, test acc:0.6921
# epoch:81, train acc:0.82, test acc:0.694
# epoch:82, train acc:0.82, test acc:0.6897
# epoch:83, train acc:0.82, test acc:0.6928
# epoch:84, train acc:0.8233333333333334, test acc:0.6947
# epoch:85, train acc:0.8333333333333334, test acc:0.6996
# epoch:86, train acc:0.8233333333333334, test acc:0.6905
# epoch:87, train acc:0.84, test acc:0.7009
# epoch:88, train acc:0.8233333333333334, test acc:0.6935
# epoch:89, train acc:0.8266666666666667, test acc:0.6955
# epoch:90, train acc:0.8366666666666667, test acc:0.7007
# epoch:91, train acc:0.8333333333333334, test acc:0.6996
# epoch:92, train acc:0.8533333333333334, test acc:0.7079
# epoch:93, train acc:0.85, test acc:0.704
# epoch:94, train acc:0.8233333333333334, test acc:0.6974
# epoch:95, train acc:0.8433333333333334, test acc:0.7057
# epoch:96, train acc:0.8466666666666667, test acc:0.7012
# epoch:97, train acc:0.8433333333333334, test acc:0.7067
# epoch:98, train acc:0.85, test acc:0.7045
# epoch:99, train acc:0.8433333333333334, test acc:0.7049
# epoch:100, train acc:0.8533333333333334, test acc:0.7052
# epoch:101, train acc:0.84, test acc:0.7117
# epoch:102, train acc:0.8566666666666667, test acc:0.7164
# epoch:103, train acc:0.86, test acc:0.7155
# epoch:104, train acc:0.87, test acc:0.7132
# epoch:105, train acc:0.8566666666666667, test acc:0.7144
# epoch:106, train acc:0.86, test acc:0.7187
# epoch:107, train acc:0.8566666666666667, test acc:0.7179
# epoch:108, train acc:0.8566666666666667, test acc:0.7239
# epoch:109, train acc:0.8566666666666667, test acc:0.7176
# epoch:110, train acc:0.8466666666666667, test acc:0.7151
# epoch:111, train acc:0.8633333333333333, test acc:0.7136
# epoch:112, train acc:0.8633333333333333, test acc:0.7193
# epoch:113, train acc:0.87, test acc:0.7119
# epoch:114, train acc:0.8533333333333334, test acc:0.7175
# epoch:115, train acc:0.86, test acc:0.7188
# epoch:116, train acc:0.8633333333333333, test acc:0.7219
# epoch:117, train acc:0.8666666666666667, test acc:0.7219
# epoch:118, train acc:0.87, test acc:0.7233
# epoch:119, train acc:0.86, test acc:0.7204
# epoch:120, train acc:0.86, test acc:0.7199
# epoch:121, train acc:0.8666666666666667, test acc:0.7227
# epoch:122, train acc:0.8633333333333333, test acc:0.7156
# epoch:123, train acc:0.86, test acc:0.7245
# epoch:124, train acc:0.8633333333333333, test acc:0.7211
# epoch:125, train acc:0.88, test acc:0.7246
# epoch:126, train acc:0.8666666666666667, test acc:0.7165
# epoch:127, train acc:0.8733333333333333, test acc:0.7206
# epoch:128, train acc:0.86, test acc:0.7169
# epoch:129, train acc:0.8566666666666667, test acc:0.7156
# epoch:130, train acc:0.8666666666666667, test acc:0.7205
# epoch:131, train acc:0.8733333333333333, test acc:0.727
# epoch:132, train acc:0.87, test acc:0.7239
# epoch:133, train acc:0.87, test acc:0.7273
# epoch:134, train acc:0.8666666666666667, test acc:0.7306
# epoch:135, train acc:0.86, test acc:0.7239
# epoch:136, train acc:0.8766666666666667, test acc:0.7299
# epoch:137, train acc:0.88, test acc:0.7242
# epoch:138, train acc:0.8733333333333333, test acc:0.7314
# epoch:139, train acc:0.8833333333333333, test acc:0.7312
# epoch:140, train acc:0.89, test acc:0.7315
# epoch:141, train acc:0.8866666666666667, test acc:0.7291
# epoch:142, train acc:0.8766666666666667, test acc:0.7287
# epoch:143, train acc:0.8966666666666666, test acc:0.7295
# epoch:144, train acc:0.89, test acc:0.7275
# epoch:145, train acc:0.8833333333333333, test acc:0.7309
# epoch:146, train acc:0.8866666666666667, test acc:0.7325
# epoch:147, train acc:0.9066666666666666, test acc:0.7353
# epoch:148, train acc:0.91, test acc:0.7351
# epoch:149, train acc:0.9066666666666666, test acc:0.7385
# epoch:150, train acc:0.9066666666666666, test acc:0.7342
# epoch:151, train acc:0.9133333333333333, test acc:0.7315
# epoch:152, train acc:0.9033333333333333, test acc:0.7305
# epoch:153, train acc:0.91, test acc:0.7309
# epoch:154, train acc:0.9, test acc:0.7279
# epoch:155, train acc:0.9066666666666666, test acc:0.7316
# epoch:156, train acc:0.91, test acc:0.7355
# epoch:157, train acc:0.9166666666666666, test acc:0.7351
# epoch:158, train acc:0.9033333333333333, test acc:0.7286
# epoch:159, train acc:0.9033333333333333, test acc:0.7328
# epoch:160, train acc:0.9, test acc:0.7348
# epoch:161, train acc:0.91, test acc:0.7419
# epoch:162, train acc:0.9066666666666666, test acc:0.7308
# epoch:163, train acc:0.89, test acc:0.7314
# epoch:164, train acc:0.91, test acc:0.7391
# epoch:165, train acc:0.91, test acc:0.7322
# epoch:166, train acc:0.9066666666666666, test acc:0.7347
# epoch:167, train acc:0.9066666666666666, test acc:0.7341
# epoch:168, train acc:0.9, test acc:0.7312
# epoch:169, train acc:0.9, test acc:0.7325
# epoch:170, train acc:0.9066666666666666, test acc:0.7368
# epoch:171, train acc:0.92, test acc:0.746
# epoch:172, train acc:0.9233333333333333, test acc:0.7453
# epoch:173, train acc:0.9166666666666666, test acc:0.7435
# epoch:174, train acc:0.9166666666666666, test acc:0.7343
# epoch:175, train acc:0.91, test acc:0.7408
# epoch:176, train acc:0.9133333333333333, test acc:0.7374
# epoch:177, train acc:0.92, test acc:0.7406
# epoch:178, train acc:0.9166666666666666, test acc:0.7353
# epoch:179, train acc:0.9066666666666666, test acc:0.7372
# epoch:180, train acc:0.9033333333333333, test acc:0.7272
# epoch:181, train acc:0.9133333333333333, test acc:0.7383
# epoch:182, train acc:0.91, test acc:0.7351
# epoch:183, train acc:0.9133333333333333, test acc:0.7293
# epoch:184, train acc:0.9233333333333333, test acc:0.7343
# epoch:185, train acc:0.9133333333333333, test acc:0.7379
# epoch:186, train acc:0.9133333333333333, test acc:0.7393
# epoch:187, train acc:0.91, test acc:0.7391
# epoch:188, train acc:0.9133333333333333, test acc:0.7432
# epoch:189, train acc:0.92, test acc:0.7424
# epoch:190, train acc:0.92, test acc:0.7481
# epoch:191, train acc:0.9233333333333333, test acc:0.7444
# epoch:192, train acc:0.9233333333333333, test acc:0.7474
# epoch:193, train acc:0.92, test acc:0.7454
# epoch:194, train acc:0.9266666666666666, test acc:0.7472
# epoch:195, train acc:0.9233333333333333, test acc:0.7424
# epoch:196, train acc:0.92, test acc:0.7431
# epoch:197, train acc:0.9166666666666666, test acc:0.7428
# epoch:198, train acc:0.92, test acc:0.741
# epoch:199, train acc:0.92, test acc:0.745
# epoch:200, train acc:0.9233333333333333, test acc:0.7389

# %%
class Dropout:
    def __init__(self, dropout_ratio=0.5):
        self.dropout_ratio = dropout_ratio
        self.mask = None
    
    def forward(self, x, train_flg=True):
        if train_flg:
            self.mask = np.random.rand()
